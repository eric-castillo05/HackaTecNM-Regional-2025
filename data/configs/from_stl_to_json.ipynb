# %%
import numpy
from stl.mesh import Mesh
import json

# %%
mesh = Mesh.from_file('../stl/chair.stl')

# %%
vectors = mesh.vectors.tolist()

# %%
vectors
# Out:
# [[[137.72662353515625, -78.906982421875, 12.398327827453613],
#   [125.20977020263672, -85.1815414428711, 10.839506149291992],
#   [125.20977020263672, -78.906982421875, 13.130217552185059]],
#  [[126.24433898925781, -87.87064361572266, 11.437085151672363],
#   [125.20977020263672, -85.1815414428711, 10.839506149291992],
#   [136.4402618408203, -87.87064361572266, 11.437085151672363]],
#  [[124.38037109375, -88.17718505859375, 12.277619361877441],
#   [126.20065307617188, -89.20182800292969, 15.122145652770996],
#   [124.40135192871094, -89.21459197998047, 15.122145652770996]],
#  [[126.20065307617188, -89.20182800292969, 15.122145652770996],
#   [125.20977020263672, -92.60091400146484, 27.571674346923828],
#   [125.20977020263672, -87.59855651855469, 15.12214469909668]],
#  [[125.20977020263672, -92.60091400146484, 27.571674346923828],
#   [126.19529724121094, -92.55128479003906, 31.562158584594727],
#   [125.20977020263672, -90.99302673339844, 31.600767135620117]],
# ...

# %%
json_data = {
    "v": vectors
}

# %%
json_data
# Out:
# {'v': [[[137.72662353515625, -78.906982421875, 12.398327827453613],
#    [125.20977020263672, -85.1815414428711, 10.839506149291992],
#    [125.20977020263672, -78.906982421875, 13.130217552185059]],
#   [[126.24433898925781, -87.87064361572266, 11.437085151672363],
#    [125.20977020263672, -85.1815414428711, 10.839506149291992],
#    [136.4402618408203, -87.87064361572266, 11.437085151672363]],
#   [[124.38037109375, -88.17718505859375, 12.277619361877441],
#    [126.20065307617188, -89.20182800292969, 15.122145652770996],
#    [124.40135192871094, -89.21459197998047, 15.122145652770996]],
#   [[126.20065307617188, -89.20182800292969, 15.122145652770996],
#    [125.20977020263672, -92.60091400146484, 27.571674346923828],
#    [125.20977020263672, -87.59855651855469, 15.12214469909668]],
#   [[125.20977020263672, -92.60091400146484, 27.571674346923828],
#    [126.19529724121094, -92.55128479003906, 31.562158584594727],
# ...

# %%
with open ('output_chair.json', 'w') as f:
    json.dump(json_data, f)

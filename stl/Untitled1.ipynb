# %%
# %pip install numpy-stl
# Out:
# Collecting numpy-stl
#   Downloading numpy_stl-3.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (from numpy-stl) (2.3.3)
# Collecting python-utils>=3.4.5 (from numpy-stl)
#   Downloading python_utils-3.9.1-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting typing_extensions>3.10.0.2 (from python-utils>=3.4.5->numpy-stl)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading numpy_stl-3.2.0-py3-none-any.whl (20 kB)
# Downloading python_utils-3.9.1-py2.py3-none-any.whl (32 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: typing_extensions, python-utils, numpy-stl
# Successfully installed numpy-stl-3.2.0 python-utils-3.9.1 typing_extensions-4.15.0
#
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from stl import mesh

# %%
model = mesh.Mesh.from_file('../chair.stl')

# %%
model
# Out:
# <Mesh: b'STL generated by ImageToStl.com' 5968 vertices>

# %%
from matplotlib import pyplot

# %%
from mpl_toolkits import mplot3d

figure = pyplot.figure()
axes = figure.add_subplot(projection='3d')
your_mesh = mesh.Mesh.from_file('../chair.stl')
axes.add_collection3d(mplot3d.art3d.Poly3DCollection(your_mesh.vectors))

scale = your_mesh.points.flatten()
axes.auto_scale_xyz(scale, scale, scale)
pyplot.show()

# %%
your_mesh.
# Out:
# array([137.72662 , -78.90698 ,  12.398328, 125.20977 , -85.18154 ,
#         10.839506, 125.20977 , -78.90698 ,  13.130218], dtype=float32)
